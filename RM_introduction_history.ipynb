# %% [markdown]
# # Random Matrix Theory (RMT)

# %% [markdown]
# ## Introduction
#
# The [**random matrix theory**](https://en.wikipedia.org/wiki/Random_matrix) means the study of the statistical properties of eigenvalues of very large matrices. Its main goal is to provide understanding of the diverse properties (most notably, **statistics of matrix eigenvalues**) of matrices with entries drawn randomly from various probability distributions traditionally referred to as the random matrix ensembles. The numerical methods used for eigenvalues computation are the **QR** method and **Power methods (direct and indirect)**. The QR method is a numerical stable algorithm and Power method is an iterative one.
#
# Random matrix theory has found many applications in physics, statistics and engineering since its inception. Although early developments were motivated by practical experimental problems, random matrices are now used in fields as diverse as **Riemann hypothesis**, **stochastic differential equations**, condensed matter physics, statistical physics, **chaotic systems**, many body systems, **quantum chaos**, disordered systems, quantum chromodynamics, **numerical linear algebra**, **neural networks**, multivariate statistics, [**information theory**](https://rd.springer.com/article/10.1007%2FBF02710326), **signal processing** and **small-world networks**.
#
# + Real eigenvalues:
#
#     + **GOE, GUE and GSE**: composed respectively of real symmetric, complex Hermitian and complex self-adjoint quaternion matrices with independent, normally distributed mean-zero entries whose variances are adjusted to ensure the invariance of their joint probability density with respect to Orthogonal (respectively, Unitary or Symplectic) similarity transformations. Such invariance is also shared by the corresponding Lebesgue measures.
#
#     + **Invariant non-Gaussian Ensembles (Girko)**: keeps the requirement of invariance of the joint probability density of all entries but relaxes the property of entries being independent.
#
# + Complex eigenvalues:
#
#     + **Circular Ensembles (COE, CUE and CSE)**: composed of complex unitary matrices sharing the same invariance properties of the measure as their Gaussian counterparts, but with eigenvalues confined to the unit circle in the complex plane rather than to the real line.
#
#     + **Ginibre Ensemble**: matrices with independent, identically and normally distributed real, complex, or quaternion real entries, and no further constraints imposed.

# %% [markdown]
# ## Brief History
#
# + **J. Wishart (Doctoral advisor: Karl Pearson)**, 1928: Fixed-size covariance matrices with Gaussian entries
#
# + **Andrei N. Kolmogorov (Wolf Prize, 1980)**, 1933, 1941: Probability theory, Linear filtering
#
# + **N. Wiener**, 1941, 1953, 1958, 1959: Control theory, Wiener process, Wiener–Kolmogorov filters, Harmonic analysis, Positive Hermitian Matrices
#
# + **J. von Neumann**, H. H. Goldstine, 1946, 1947, 1963: Condition number, Numerical analysis, Numerical linear algebra
#
#     + **First introduced the assumption of random test matrices distributed with elements from independent normals**.
#
# + **A. T. James**, 1954, 1960, 1964: Statistics, Covariance matrices
#
# + **Eugene P. Wigner (Nobel Prizes in Physics, 1963)**, 1955, 1957, 1958, 1967 (**the real start**): Nuclear Physics, **Wigner matrix**, **Wigner surmise**, **Wigner semicircle law**
#
# + **P. $Erd\ddot{o}s$ (Wolf Prize, 1983/4)**, A. $R\acute{e}nyi$, 1959, 1964, 1972, 1995; B. $Bollob\acute{a}s$, 1985, 1998: **Random graph**
#
# + **M. L. Mehta** and M. Gaudin, 1960: Nuclear Physics, Eigenvalue density
#
# + **F. J. Dyson (Wolf Prize, 1981; Academic advisor:	Hans Bethe)**, 1962, 1963, 1970, 1972, 1976: **Dyson-Brownian motion** , Statistics, Threefold way, **Dyson index**, Circular ensemble
#
# + **L. K. Hua (华罗庚)**, 1963 (Chinese edition, 1958): Multivariate harmonic analysis
#
# + **J. Ginibre**, 1965: **Ginibre ensemble**
#
# + **L. Arnold**, 1967: Eigenvalues distribution
#
# + **V. $Mar\check{c}enko$**, **L. Pastur (AMS Fellow, 2012)**, 1967: [$Mar\check{c}enko$-Pastur distribution](https://en.wikipedia.org/wiki/Marchenko–Pastur_distribution)
#
# + **H. L. Montgomery (AMS Fellow, 2012)**, 1972, 1973: Riemann $\zeta$ function
#
# + **Jack W. Silverstein (Institute of Mathematical Statistics Fellow)**, 1976-: Spectral analysis of large random matrices, Array processing; [Theory of Large Dimensional Random Matrices for Engineers](http://www4.ncsu.edu/~jack/IEEE.pdf)
#
# + G. W. Stewart, 1980: Condition estimator
#
# + J. Komlos, 1981: Eigenvalues of Random Symmetric Matrices
#
# + **Lloyd N. Trefethen (AMS Fellow; Royal Society Fellow, 2005; NAE Fellow, 2007)**, 1990: Numerical linear algebra, Stability analysis, **Pseudospectra**, **Gaussian elimination of random matrices**
#
# + **Zhidong Bai (白志东, Third World Academy of Sciences Fellow; Institute of Mathematical Statistics Fellow)**, 1984-: Spectral analysis of large-dimensional random matrices, circular law; [METHODOLOGIES IN SPECTRAL ANALYSIS OF LARGE DIMENSIONAL RANDOM MATRICES, A REVIEW](http://www3.stat.sinica.edu.tw/statistica/oldpdf/A9n31.pdf)
#
# + **V. L. Girko**, 1985: [**Circular Law**](https://en.wikipedia.org/wiki/Circular_law), Random determinant
#
# + **D. Voiculescu (AMS Fellow, 2012)**, 1986, 1991; R. Speicher, 2003, 2005; P. Biane: **Free Probability Theory**, von Neumann algebra
#
# + **Alan Edelman (Gordon Bell Prize, 1989; SIAM Fellow, 2011; AMS Fellow, 2015; IEEE Fellow, 2018; Doctoral advisor: Lloyd N. Trefethen)**, 1988, 1989, 2004: Expectation of real eigenvalues number, **Condition numbers**, Smallest singular value of random matrices (also known as the **Edelman's law**); [Random Matrix Theory](https://web.eecs.umich.edu/~rajnrao/Acta05rmt.pdf)
#
#     + The limitations on solving large systems of equations are computer memory and speed. The speed of computation, however, is not only measured by clocking hardware; it also depends on numerical stability, and for iterative methods, on convergence rates.
#
#     + In fact, the larger the size of the matrix the more predictable it becomes. This is partly because of the **central limit theorem**.
#
#     + The **weight function** associated with classical orthogonal polynomials plays an important role in random matrix theory.
#
# + [**Peter J. Forrester**](http://researchers.ms.unimelb.edu.au/~pjforr@unimelb/), 1992-: LIS, Log-gases, Spectral edge, Hard-to-soft edge transition, **Integrable system**, $Painlev\acute{e}$ equation, $\tau$ function, L-function, **Golden-Thompson inequality**, [**Big data**](https://acems.org.au/projects/random-matrices-and-big-data-sets); [Developments in random matrix theory](https://arxiv.org/pdf/cond-mat/0303207.pdf), [A. HURWITZ AND THE ORIGINS OF RANDOM MATRIX THEORY IN MATHEMATICS](http://statweb.stanford.edu/~cgates/PERSI/papers/rmpart3a.pdf)
#
# + **C. Tracy (AAAS Fellow, 2006; AMS Fellow, 2012)**, **H. Widom (AAAS Fellow, 2006; AMS Fellow, 2012)**, 1993, 1994, 2000, 20001, 2002, 2009: [Tracy-Widom distribution](https://en.wikipedia.org/wiki/Tracy–Widom_distribution), $Painlev\acute{e}$ equation, Asymptotic analysis of **Toeplitz determinants**, Totally asymmetric simple exclusion process (**TASEP**)
#
# + **P. Diaconis (MacArthur Fellow, 1982; NAS Fellow, 1995; AMS Fellow, 2012)**, 1994, 2001, 2013: Eigenvalues of random matrices, **Shuffling cards**, Random graph models; [What is a Random Matrix?](http://www.ams.org/notices/200511/what-is.pdf)
#
# + M. Adler, **P. van Moerbeke**, 1995, 2001: Vertex operators, **Virasoro algebra**, $Painlev\acute{e}$ transcendents, **Integrable system**, Integrable lattices
#
# + Y. V. Fyodorov, 1997, 2003, 2008, 2009, 2010, 2013: Almost Hermitian random matrix, **Riemann-Hilbert (RH) approach**, **Fluctuation**, **High-dimensional random fields**; [Random matrix theory](http://www.scholarpedia.org/article/Random_matrix_theory)
#
# + **G. Ben Arous (Member of Bourbaki; AAAS Fellow, 2015)**, **Alice Guionnet (Doctoral advisor: G. Ben Arous)**, S. $P\acute{e}ch\acute{e}$ (Doctoral advisor: G. Ben Arous), 1997, 2012, 2016, 2017: **Integrable system**, **Large deviations**, **Single ring law**, **Phase transition**, Large random matrices, **Complexity of random functions of many variables**; [An introduction to random matrices](https://cims.nyu.edu/~zeitouni/cupbook.pdf)
#
# + **Anthony Zee (徐一鸿, Ed Witten as his teaching assistant)**, 1997, 2001: Circular law, **Single ring law**, Green function, **RNA Folding**
#
# + A. Odlyzko, 1998: **Longest Increasing Subsequence (LIS)**
#
# + **J. Baik (Doctoral advisor: P. Deift)**, **P. Deift(AAAS Fellow, 2003; NAS Fellow, 2009; AMS Fellow, 2012)**, **K. Johansson**, 1999: LIS, Eigenvalues distribution
#
# + **A. Borodin**, 1999, 2000, 2009, 2015: LIS, **Determinantal Point Process (DPP)**, [**Integrable probability**](https://arxiv.org/pdf/1212.3351.pdf)
#
# + A. Soshnikov, 1999, 2001: Universality at the edge of the spectrum, [Quantum Chaos](http://scholarpedia.org/article/Quantum_chaos); [Random matrices and quantum chaos](http://www.pnas.org/content/pnas/98/19/10531.full.pdf)
#
# + P. Bleher, **A. Its (AMS Fellow, 2012)**, 1999; **P. Deift (AAAS Fellow, 2003; NAS Fellow, 2009; AMS Fellow, 2012)**, X. Zhou, 1997, 1999; **A. B. J. Kuijlaars (AMS Fellow, 2013)**, 2000, 2003; P. Deift, **S. Olver** (father: **Peter J. Olver**; grandfather: **Frank W. J. Olver**), T. Trogdon, G. Menon, 2000, 2004, 2014-2017: **Riemann-Hilbert (RH) approach** to the asymptotics of **Orthogonal Polynomials**, Universality, Equilibrium measure, Numerical computation, **Smoothed analysis**, **Transport system**; [UNIVERSALITY FOR MATHEMATICAL AND PHYSICAL SYSTEMS](http://icm2006.org/proceedings/Vol_I/11.pdf), [Some Open Problems in Random Matrix Theory and the Theory of Integrable Systems. II](https://arxiv.org/pdf/1703.04931.pdf), [Lectures on Random Matrix Theory](http://www.dam.brown.edu/people/menon/publications/notes/rmt-notes.pdf)
#
# + **Albert-L$\acute{a}$szl$\acute{o}$ Barab$\acute{a}$si (APS Fellow)**, R$\acute{e}$ka Albert (Doctoral advisor: Albert-L$\acute{a}$szl$\acute{o}$ Barab$\acute{a}$si), 1999; **Van H. Vu (AMS Fellow, 2012)**, 2003; **Mark J. Newman**; **Steven Strogatz (SIAM Fellow; AAAS Fellow; APS Fellow; AMS Fellow)**, Duncan J. Watts (Doctoral advisor: Steven Strogatz): **Complex network** (**small-world** network, **scale-free**, **power law**), Random power law graphs, Financial risk management; [Spectra of “real-world” graphs: Beyond the semicircle law](https://journals.aps.org/pre/pdf/10.1103/PhysRevE.64.026704)
#
# + **M. Hairer (Royal Society Fellow, 2014; Fields Medal, 2014; AMS Fellow, 2015; father: Ernst Hairer; wife: Xuemei Li (李雪梅))**, 1999-: Statistical mechanics, Stochastic PDEs, KPZ equation, Stochastic process, Probability; [An Introduction to Stochastic PDEs](http://hairer.org/notes/SPDEs.pdf), [Solving the KPZ equation](http://www.hairer.org/papers/KPZ.pdf)
#
# + **K. Johansson**, 2000, 2005: Shape fluctuations, Determinantal process
#
# + J. P. Keating, 2000: Riemann $\zeta$ function, **L-function**
#
# + **J. P. Bouchaud (French Academy of Sciences member, 2017)**, **M. Potters**, 2000, 2007, 2009: **Finance**, Singular value spectra
#
# + **David L. Donoho (MacArthur Fellow, 1991; AAAS Fellow, 1992; SIAM Fellow, 2009; AMS Fellow, 2012; Shaw Prize for Mathematics, 2013)**, 2000, 2006, 2017: [High-dimensional data analysis](http://statweb.stanford.edu/~donoho/Lectures/AMS2000/Curses.pdf), [**Compressed Sensing**](http://statweb.stanford.edu/~donoho/Reports/2004/CompressedSensing091604.pdf), [Data Science](http://courses.csail.mit.edu/18.337/2015/docs/50YearsDataScience.pdf), **Deep learning theory**
#
#     > **Doctoral students**:
#
#     + **Emmanuel Candes** (MacArthur Fellow, 2017; IEEE Fellow, 2018; AMS Fellow, 2018): Compressed Sensing, Wavelet, Curvelet, Ridgelet, Matrix completion
#
#     + **Jianqing Fan (范剑青)**
#
# + **I. M. Johnstone**, 2001: **Principal Component Analysis (PCA)**, Principal eigenvectors
#
# + I. Dumitriu (Doctoral Advisor: Alan Edelman), A. Edelman, 2003, 2004: **$\beta$-ensemble**, **Multivariate Orthogonal Polynomials(MOPS)**
#
# + **Shang-Hua Teng(滕尚华, Godel Prize, 2008, 2015; ACM Fellow, 2009)**, **Daniel Spielman(Godel Prize, 2008, 2015; ACM Fellow, 2010; MacArthur Fellow, 2012)**, 2004: Smoothed analysis
#
# + **A. M. Tulino (IEEE Fellow, 2013)**, S. Verdu, 2004: **Wireless communications**; [Random matrix theory and wireless communications](http://web.mit.edu/18.325/www/atsv.pdf)
#
# + **Dimitris Achlioptas**, 2004, 2005: **Data analysis**, **Machine Learning**, Low-rank matrix approximation; [Random Matrices in Data Analysis](https://users.soe.ucsc.edu/~optas/papers/matrices.pdf)
#
#     +  **Accelerate spectral computations by injecting sparsification/quantization “noise”**.
#
# + **N. R. Rao (Doctoral Advisor: Alan Edelman)**, A. Edelman, 2005, 2007: Polynomial method, Eigenvalues and eigenvectors, **Low rank approximation**
#
# + R. D. Sutton (Doctoral Advisor: Alan Edelman), A. Edelman, 2006: **Stochastic operator approach**, **Black-Scholes model**
#
# + G. Akemann, 2007: **Integrable system**
#
# + **T. Tao (陶哲轩, Fields Medal, 2006; Royal Society Fellow, 2007)**, **V. Vu**, 2007, 2009, 2010: Circular law, Hardy–Littlewood prime tuples conjecture, Universality, Discrete random matrices, Compressed sensing; [Topics in random matrix theory](http://www.math.hkbu.edu.hk/~ttang/UsefulCollections/matrix-book-2011-02.pdf)
#
# + Alan Edelman, Per-Olof Persson, 2008: [Numerical Methods for Eigenvalue Distributions of Random Matrices](https://arxiv.org/pdf/math-ph/0501068.pdf)
#
# + **J. A. Tropp**, 2008, 2009, 2011, 2012, 2014, 2015, 2016: **Matrix Concentration Inequality**; [An Introduction to Matrix Concentration Inequalities](https://arxiv.org/pdf/1501.01571.pdf)
#
# + **Romain Couillet**, **$M\acute{e}rouane$ Debbah (IEEE Fellow)**, **Florent Benaych-Georges**, 2008-: Wireless communication, Spectral clustering, Free deconvolution, **Neural network**, Machine learning; [Random Matrix Methods for Wireless Communications](http://s1.nonlinear.ir/epublish/book/Random_Matrix_Methods_for_Wireless_Communications_9781107011632.PDF)
#
# + F. Bornemann, 2010: [ON THE NUMERICAL EVALUATION OF DISTRIBUTIONS IN RANDOM MATRIX THEORY: A REVIEW](http://www-m3.ma.tum.de/foswiki/pub/M3/Allgemeines/FolkmarBornemannPublications/NumericalRMT.pdf)
#
# + **R. Vershynin**, 2010, 2011: **Non-asymptotic random matrices**, [**RandNLA**](https://arxiv.org/pdf/1712.08880.pdf); [High-Dimensional Probability: An Introduction with Applications in Data Science](https://www.math.uci.edu/~rvershyn/papers/HDP-book/HDP-book.pdf)
#
# + Ivan Corwin (Doctoral Advisor: G. Ben Arous), 2011-: Random growth process (q-TASEP and ASEP), Random Polymer, KPZ universality
#
# + **L. Erdos**, **Horng-Tzer Yau (姚鸿泽, MacArthur Fellow, 2000; AMS Fellow, 2012)**, 2012, 2013, 2014: Bulk universality, Edge universality, Local spectral statistics, Matrix Dyson Equation
#
# + **A. Auffinger (Doctoral Advisor: G. Ben Arous)**, G. Ben Arous, 2013: **Complexity of spin glasses**
#
# + **Robert C. Qiu (邱才明, IEEE Fellow, 2015)**, 2013-: Cognitive network, Smart Grid, Neural network, Big data
#
# + **Xiuyuan Cheng (陈修远; Doctoral Advisor: Amit Singer)**, Amit Singer, 2013, 2014: High-dimensional data analysis, Spectrum of kernel matrices; [Random Matrices in High-dimensional Data Analysis](https://dataspace.princeton.edu/jspui/bitstream/88435/dsp01wh246s26t/1/Cheng_princeton_0181D_10781.pdf)
#
# + **Deep Learning**, 2014-: Levent Sagun (Academic advisors: G. Ben Arous, Yann Lecun), G. Ben Arous, **Yann Lecun (NAE Fellow, 2018)**, Anna Choromanska, S. Ganguli, **Y. Bengio**, R. Couillet, Hafiz Tiomoko Ali, J. Pennington
#
# + **Quantum Information**, 2016: [Random matrix techniques in quantum information theory](https://arxiv.org/pdf/1509.04689.pdf)
#
# + **Stephen Shenker (MacArthur Fellow, 1987; AAAS Fellow)**, 2017: **Black holes**, Quantum chaos
#
# + **Culture**, 2018: [A random matrix perspective of cultural structure](https://arxiv.org/pdf/1803.04324.pdf)

# %% [markdown]
# ## More Readings
#
# + [The 70th anniversary of the distribution of random matrices: A survey](https://core.ac.uk/download/pdf/82102389.pdf) (2002)
#
# + [What is Quantum Chaos?](http://www.ams.org/notices/200801/tx080100032p.pdf) (2008)
#
# + Peter J. Forrester, **Log-Gases and Random Matrices**, edited by Martin Bridson, Terry Lyons, and Peter Sarnak, Princeton University Press, 2010.
#
# + Zhidong Bai, Jack W. Silverstein, **Spectral Analysis of Large Dimensional Random Matrices**, Springer-Verlag New York, 2010.
#
# + **Oxford Handbook on Random Matrix theory**, edited by Akemann G.; Baik, J. ; Di Francesco P. , Oxford University Press, 2011.
#
# + [Determinantal Point Processes for Machine Learning](http://www.alexkulesza.com/pubs/dpps_fnt12.pdf) (2012)
#
# + [Random Matrices in Physics](https://quark.phy.bnl.gov/www/colloquia_FY16_files/weidenmueller.pdf) (2015)
